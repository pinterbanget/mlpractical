# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the MLP2024_25_CW1_Spec.pdf (see Learn,  Assignment Submission, Coursework 1). The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for num_epochs epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
    ax_1.set_ylabel('Error')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    ax_2.set_xlabel('Accuracy')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
import sys
# sys.path.append('/path/to/mlpractical')
from mlp.data_providers import MNISTDataProvider, EMNISTDataProvider

# Seed a random number generator
seed = 11102019 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = EMNISTDataProvider('valid', batch_size=batch_size, rng=rng)
# Out:
# KeysView(NpzFile '/Users/rj/documents/codes/mlpractical/data/emnist-train.npz' with keys: inputs, targets)
# KeysView(NpzFile '/Users/rj/documents/codes/mlpractical/data/emnist-valid.npz' with keys: inputs, targets)

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# %pip install tqdm

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser

# Setup hyperparameters
learning_rate = 0.001
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

# Create model with ONE hidden layer
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
# Out:
# Collecting tqdm
#   Using cached tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.66.5-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.66.5
# Note: you may need to restart the kernel to use updated packages.
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 3.8s to complete
#     error(train)=9.30e-01, acc(train)=7.32e-01, error(valid)=9.51e-01, acc(valid)=7.28e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 5.5s to complete
#     error(train)=7.21e-01, acc(train)=7.86e-01, error(valid)=7.60e-01, acc(valid)=7.77e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 3.9s to complete
#     error(train)=6.27e-01, acc(train)=8.06e-01, error(valid)=6.80e-01, acc(valid)=7.91e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 3.6s to complete
#     error(train)=5.54e-01, acc(train)=8.27e-01, error(valid)=6.20e-01, acc(valid)=8.06e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 3.2s to complete
#     error(train)=5.22e-01, acc(train)=8.35e-01, error(valid)=5.97e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 3.7s to complete
#     error(train)=4.92e-01, acc(train)=8.40e-01, error(valid)=5.81e-01, acc(valid)=8.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 7: 3.0s to complete
#     error(train)=4.66e-01, acc(train)=8.49e-01, error(valid)=5.68e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 8: 3.0s to complete
#     error(train)=4.37e-01, acc(train)=8.57e-01, error(valid)=5.44e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 9: 3.0s to complete
#     error(train)=4.18e-01, acc(train)=8.62e-01, error(valid)=5.39e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 10: 2.9s to complete
#     error(train)=4.13e-01, acc(train)=8.62e-01, error(valid)=5.47e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 11: 3.0s to complete
#     error(train)=4.02e-01, acc(train)=8.64e-01, error(valid)=5.44e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 12: 3.1s to complete
#     error(train)=3.88e-01, acc(train)=8.69e-01, error(valid)=5.37e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 13: 2.9s to complete
#     error(train)=3.78e-01, acc(train)=8.72e-01, error(valid)=5.36e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 14: 3.1s to complete
#     error(train)=3.66e-01, acc(train)=8.76e-01, error(valid)=5.41e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 15: 3.1s to complete
#     error(train)=3.60e-01, acc(train)=8.77e-01, error(valid)=5.37e-01, acc(valid)=8.29e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 16: 3.1s to complete
#     error(train)=3.60e-01, acc(train)=8.74e-01, error(valid)=5.45e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 17: 3.2s to complete
#     error(train)=3.40e-01, acc(train)=8.84e-01, error(valid)=5.34e-01, acc(valid)=8.32e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 18: 4.1s to complete
#     error(train)=3.44e-01, acc(train)=8.81e-01, error(valid)=5.50e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 19: 4.0s to complete
#     error(train)=3.34e-01, acc(train)=8.85e-01, error(valid)=5.43e-01, acc(valid)=8.31e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 20: 6.7s to complete
#     error(train)=3.25e-01, acc(train)=8.86e-01, error(valid)=5.43e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 21: 6.0s to complete
#     error(train)=3.28e-01, acc(train)=8.84e-01, error(valid)=5.54e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 22: 4.3s to complete
#     error(train)=3.23e-01, acc(train)=8.86e-01, error(valid)=5.56e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 23: 7.0s to complete
#     error(train)=3.10e-01, acc(train)=8.92e-01, error(valid)=5.53e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 24: 3.1s to complete
#     error(train)=3.07e-01, acc(train)=8.92e-01, error(valid)=5.61e-01, acc(valid)=8.28e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 25: 2.9s to complete
#     error(train)=2.98e-01, acc(train)=8.96e-01, error(valid)=5.54e-01, acc(valid)=8.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 26: 6.0s to complete
#     error(train)=3.00e-01, acc(train)=8.95e-01, error(valid)=5.70e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 27: 6.0s to complete
#     error(train)=2.88e-01, acc(train)=8.97e-01, error(valid)=5.66e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 28: 3.8s to complete
#     error(train)=2.91e-01, acc(train)=8.97e-01, error(valid)=5.74e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 29: 3.7s to complete
#     error(train)=2.85e-01, acc(train)=8.99e-01, error(valid)=5.73e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 30: 3.3s to complete
#     error(train)=2.82e-01, acc(train)=9.00e-01, error(valid)=5.77e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 31: 3.1s to complete
#     error(train)=2.77e-01, acc(train)=9.01e-01, error(valid)=5.87e-01, acc(valid)=8.23e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 32: 4.7s to complete
#     error(train)=2.76e-01, acc(train)=9.02e-01, error(valid)=5.89e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 33: 6.1s to complete
#     error(train)=2.76e-01, acc(train)=9.01e-01, error(valid)=6.11e-01, acc(valid)=8.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 34: 2.9s to complete
#     error(train)=2.79e-01, acc(train)=8.98e-01, error(valid)=6.13e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 35: 3.3s to complete
#     error(train)=2.64e-01, acc(train)=9.05e-01, error(valid)=6.02e-01, acc(valid)=8.26e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 36: 3.6s to complete
#     error(train)=2.61e-01, acc(train)=9.06e-01, error(valid)=6.11e-01, acc(valid)=8.26e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 37: 5.2s to complete
#     error(train)=2.56e-01, acc(train)=9.08e-01, error(valid)=6.09e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 38: 3.9s to complete
#     error(train)=2.52e-01, acc(train)=9.08e-01, error(valid)=6.11e-01, acc(valid)=8.26e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 39: 5.5s to complete
#     error(train)=2.52e-01, acc(train)=9.09e-01, error(valid)=6.29e-01, acc(valid)=8.20e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 40: 3.6s to complete
#     error(train)=2.43e-01, acc(train)=9.12e-01, error(valid)=6.19e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 41: 3.5s to complete
#     error(train)=2.43e-01, acc(train)=9.12e-01, error(valid)=6.26e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 42: 3.4s to complete
#     error(train)=2.54e-01, acc(train)=9.07e-01, error(valid)=6.42e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 43: 4.9s to complete
#     error(train)=2.44e-01, acc(train)=9.11e-01, error(valid)=6.50e-01, acc(valid)=8.20e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 44: 3.3s to complete
#     error(train)=2.38e-01, acc(train)=9.13e-01, error(valid)=6.41e-01, acc(valid)=8.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 45: 3.8s to complete
#     error(train)=2.48e-01, acc(train)=9.07e-01, error(valid)=6.54e-01, acc(valid)=8.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 46: 4.8s to complete
#     error(train)=2.32e-01, acc(train)=9.16e-01, error(valid)=6.55e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 47: 7.5s to complete
#     error(train)=2.33e-01, acc(train)=9.14e-01, error(valid)=6.63e-01, acc(valid)=8.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 48: 3.4s to complete
#     error(train)=2.22e-01, acc(train)=9.20e-01, error(valid)=6.64e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 49: 2.7s to complete
#     error(train)=2.36e-01, acc(train)=9.13e-01, error(valid)=6.78e-01, acc(valid)=8.17e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 50: 2.7s to complete
#     error(train)=2.25e-01, acc(train)=9.17e-01, error(valid)=6.77e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 51: 3.2s to complete
#     error(train)=2.22e-01, acc(train)=9.18e-01, error(valid)=6.79e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 52: 3.9s to complete
#     error(train)=2.19e-01, acc(train)=9.18e-01, error(valid)=6.97e-01, acc(valid)=8.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 53: 2.7s to complete
#     error(train)=2.29e-01, acc(train)=9.16e-01, error(valid)=7.08e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 54: 3.3s to complete
#     error(train)=2.16e-01, acc(train)=9.20e-01, error(valid)=7.00e-01, acc(valid)=8.17e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 55: 5.2s to complete
#     error(train)=2.12e-01, acc(train)=9.22e-01, error(valid)=6.98e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 56: 3.7s to complete
#     error(train)=2.17e-01, acc(train)=9.20e-01, error(valid)=7.14e-01, acc(valid)=8.15e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 57: 4.0s to complete
#     error(train)=2.13e-01, acc(train)=9.20e-01, error(valid)=7.23e-01, acc(valid)=8.16e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 58: 3.6s to complete
#     error(train)=2.13e-01, acc(train)=9.21e-01, error(valid)=7.21e-01, acc(valid)=8.15e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 59: 2.7s to complete
#     error(train)=2.08e-01, acc(train)=9.23e-01, error(valid)=7.29e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 60: 2.6s to complete
#     error(train)=2.10e-01, acc(train)=9.22e-01, error(valid)=7.24e-01, acc(valid)=8.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 61: 3.0s to complete
#     error(train)=2.06e-01, acc(train)=9.23e-01, error(valid)=7.40e-01, acc(valid)=8.13e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 62: 2.6s to complete
#     error(train)=1.96e-01, acc(train)=9.28e-01, error(valid)=7.33e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 63: 3.1s to complete
#     error(train)=1.95e-01, acc(train)=9.29e-01, error(valid)=7.46e-01, acc(valid)=8.15e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 64: 2.6s to complete
#     error(train)=2.06e-01, acc(train)=9.21e-01, error(valid)=7.65e-01, acc(valid)=8.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 65: 2.8s to complete
#     error(train)=1.97e-01, acc(train)=9.26e-01, error(valid)=7.59e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 66: 2.8s to complete
#     error(train)=1.96e-01, acc(train)=9.27e-01, error(valid)=7.61e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 67: 2.7s to complete
#     error(train)=1.97e-01, acc(train)=9.26e-01, error(valid)=7.76e-01, acc(valid)=8.12e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 68: 3.1s to complete
#     error(train)=2.06e-01, acc(train)=9.21e-01, error(valid)=7.95e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 69: 3.6s to complete
#     error(train)=1.91e-01, acc(train)=9.29e-01, error(valid)=7.80e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 70: 4.9s to complete
#     error(train)=2.03e-01, acc(train)=9.23e-01, error(valid)=7.92e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 71: 4.2s to complete
#     error(train)=1.91e-01, acc(train)=9.28e-01, error(valid)=7.96e-01, acc(valid)=8.13e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 72: 5.1s to complete
#     error(train)=1.88e-01, acc(train)=9.29e-01, error(valid)=8.01e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 73: 4.8s to complete
#     error(train)=1.86e-01, acc(train)=9.30e-01, error(valid)=8.08e-01, acc(valid)=8.06e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 74: 3.2s to complete
#     error(train)=1.86e-01, acc(train)=9.30e-01, error(valid)=8.12e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 75: 2.7s to complete
#     error(train)=1.78e-01, acc(train)=9.34e-01, error(valid)=8.16e-01, acc(valid)=8.13e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 76: 2.6s to complete
#     error(train)=1.87e-01, acc(train)=9.27e-01, error(valid)=8.34e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 77: 2.6s to complete
#     error(train)=1.83e-01, acc(train)=9.30e-01, error(valid)=8.31e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 78: 2.9s to complete
#     error(train)=1.85e-01, acc(train)=9.30e-01, error(valid)=8.33e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 79: 3.0s to complete
#     error(train)=1.75e-01, acc(train)=9.34e-01, error(valid)=8.43e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 80: 4.4s to complete
#     error(train)=1.78e-01, acc(train)=9.33e-01, error(valid)=8.47e-01, acc(valid)=8.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 81: 3.4s to complete
#     error(train)=1.72e-01, acc(train)=9.36e-01, error(valid)=8.48e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 82: 5.2s to complete
#     error(train)=1.75e-01, acc(train)=9.33e-01, error(valid)=8.55e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 83: 4.6s to complete
#     error(train)=1.70e-01, acc(train)=9.35e-01, error(valid)=8.64e-01, acc(valid)=8.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 84: 6.2s to complete
#     error(train)=1.69e-01, acc(train)=9.36e-01, error(valid)=8.64e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 85: 3.8s to complete
#     error(train)=1.73e-01, acc(train)=9.33e-01, error(valid)=8.72e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 86: 5.8s to complete
#     error(train)=1.67e-01, acc(train)=9.36e-01, error(valid)=8.79e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 87: 4.8s to complete
#     error(train)=1.76e-01, acc(train)=9.33e-01, error(valid)=9.06e-01, acc(valid)=8.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 88: 4.2s to complete
#     error(train)=1.76e-01, acc(train)=9.32e-01, error(valid)=9.09e-01, acc(valid)=8.04e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 89: 3.2s to complete
#     error(train)=1.76e-01, acc(train)=9.32e-01, error(valid)=9.13e-01, acc(valid)=8.06e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 90: 3.2s to complete
#     error(train)=1.63e-01, acc(train)=9.39e-01, error(valid)=9.13e-01, acc(valid)=8.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 91: 3.4s to complete
#     error(train)=1.59e-01, acc(train)=9.40e-01, error(valid)=9.10e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 92: 3.1s to complete
#     error(train)=1.57e-01, acc(train)=9.41e-01, error(valid)=9.14e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 93: 3.8s to complete
#     error(train)=1.63e-01, acc(train)=9.38e-01, error(valid)=9.26e-01, acc(valid)=8.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 94: 3.9s to complete
#     error(train)=1.63e-01, acc(train)=9.37e-01, error(valid)=9.36e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 95: 3.1s to complete
#     error(train)=1.61e-01, acc(train)=9.39e-01, error(valid)=9.45e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 96: 3.8s to complete
#     error(train)=1.57e-01, acc(train)=9.40e-01, error(valid)=9.42e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 97: 3.1s to complete
#     error(train)=1.62e-01, acc(train)=9.38e-01, error(valid)=9.60e-01, acc(valid)=8.07e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 98: 3.6s to complete
#     error(train)=1.57e-01, acc(train)=9.40e-01, error(valid)=9.61e-01, acc(valid)=8.09e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 99: 3.3s to complete
#     error(train)=1.54e-01, acc(train)=9.41e-01, error(valid)=9.56e-01, acc(valid)=8.08e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 100: 3.1s to complete
#     error(train)=1.56e-01, acc(train)=9.40e-01, error(valid)=9.83e-01, acc(valid)=8.03e-01

# %%
# dropout .97 with test data
# we can use test data as the argument for the validation data parameter
# from the train_model_and_plot_stats function

from mlp.layers import DropoutLayer
from mlp.layers import AffineLayer, ReluLayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit
from mlp.learning_rules import AdamLearningRule
from mlp.optimisers import Optimiser
from mlp import DEFAULT_SEED

# Setup hyperparameters
learning_rate = 1e-4
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 47, 128
incl_prob = 0.97

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)

train_data = EMNISTDataProvider('train', batch_size=batch_size, rng=rng)
test_data = EMNISTDataProvider('test', batch_size=batch_size, rng=rng)


model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # first hidden layer
    ReluLayer(),
    DropoutLayer(rng=np.random.RandomState(DEFAULT_SEED), incl_prob=incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # second hidden layer
    ReluLayer(),
    DropoutLayer(rng=np.random.RandomState(DEFAULT_SEED), incl_prob=incl_prob),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # third hidden layer
    ReluLayer(),
    DropoutLayer(rng=np.random.RandomState(DEFAULT_SEED), incl_prob=incl_prob),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
droppie_97 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, test_data, num_epochs, stats_interval, notebook=True)
# Out:
# KeysView(NpzFile '/Users/rj/documents/codes/mlpractical/data/emnist-train.npz' with keys: inputs, targets)
# KeysView(NpzFile '/Users/rj/documents/codes/mlpractical/data/emnist-test.npz' with keys: inputs, targets)
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 1: 15.1s to complete
#     error(train)=1.44e+00, acc(train)=6.06e-01, error(valid)=1.46e+00, acc(valid)=5.96e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 2: 13.1s to complete
#     error(train)=1.17e+00, acc(train)=6.72e-01, error(valid)=1.20e+00, acc(valid)=6.61e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 3: 25.3s to complete
#     error(train)=1.02e+00, acc(train)=7.08e-01, error(valid)=1.06e+00, acc(valid)=6.94e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 4: 20.9s to complete
#     error(train)=9.16e-01, acc(train)=7.33e-01, error(valid)=9.53e-01, acc(valid)=7.18e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 5: 26.5s to complete
#     error(train)=8.41e-01, acc(train)=7.51e-01, error(valid)=8.86e-01, acc(valid)=7.32e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 6: 25.3s to complete
#     error(train)=7.81e-01, acc(train)=7.66e-01, error(valid)=8.30e-01, acc(valid)=7.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 7: 12.5s to complete
#     error(train)=7.37e-01, acc(train)=7.77e-01, error(valid)=7.88e-01, acc(valid)=7.55e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 8: 18.4s to complete
#     error(train)=7.01e-01, acc(train)=7.86e-01, error(valid)=7.58e-01, acc(valid)=7.64e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 9: 19.1s to complete
#     error(train)=6.66e-01, acc(train)=7.95e-01, error(valid)=7.27e-01, acc(valid)=7.71e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 10: 13.6s to complete
#     error(train)=6.38e-01, acc(train)=8.02e-01, error(valid)=6.99e-01, acc(valid)=7.80e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 11: 14.5s to complete
#     error(train)=6.14e-01, acc(train)=8.08e-01, error(valid)=6.77e-01, acc(valid)=7.84e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 12: 15.9s to complete
#     error(train)=5.93e-01, acc(train)=8.15e-01, error(valid)=6.60e-01, acc(valid)=7.91e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 13: 21.5s to complete
#     error(train)=5.73e-01, acc(train)=8.20e-01, error(valid)=6.41e-01, acc(valid)=7.95e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 14: 9.7s to complete
#     error(train)=5.55e-01, acc(train)=8.24e-01, error(valid)=6.27e-01, acc(valid)=7.99e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 15: 8.9s to complete
#     error(train)=5.41e-01, acc(train)=8.28e-01, error(valid)=6.16e-01, acc(valid)=8.01e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 16: 9.0s to complete
#     error(train)=5.31e-01, acc(train)=8.28e-01, error(valid)=6.12e-01, acc(valid)=8.04e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 17: 11.2s to complete
#     error(train)=5.17e-01, acc(train)=8.33e-01, error(valid)=6.01e-01, acc(valid)=8.05e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 18: 9.3s to complete
#     error(train)=5.04e-01, acc(train)=8.37e-01, error(valid)=5.88e-01, acc(valid)=8.10e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 19: 9.4s to complete
#     error(train)=4.93e-01, acc(train)=8.40e-01, error(valid)=5.79e-01, acc(valid)=8.11e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 20: 9.1s to complete
#     error(train)=4.84e-01, acc(train)=8.42e-01, error(valid)=5.72e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 21: 8.9s to complete
#     error(train)=4.77e-01, acc(train)=8.44e-01, error(valid)=5.69e-01, acc(valid)=8.14e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 22: 8.9s to complete
#     error(train)=4.66e-01, acc(train)=8.47e-01, error(valid)=5.57e-01, acc(valid)=8.17e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 23: 9.8s to complete
#     error(train)=4.56e-01, acc(train)=8.50e-01, error(valid)=5.50e-01, acc(valid)=8.19e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 24: 12.7s to complete
#     error(train)=4.52e-01, acc(train)=8.50e-01, error(valid)=5.46e-01, acc(valid)=8.22e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 25: 9.0s to complete
#     error(train)=4.43e-01, acc(train)=8.53e-01, error(valid)=5.44e-01, acc(valid)=8.21e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 26: 8.8s to complete
#     error(train)=4.36e-01, acc(train)=8.55e-01, error(valid)=5.36e-01, acc(valid)=8.25e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 27: 10.4s to complete
#     error(train)=4.30e-01, acc(train)=8.56e-01, error(valid)=5.34e-01, acc(valid)=8.24e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 28: 10.2s to complete
#     error(train)=4.23e-01, acc(train)=8.59e-01, error(valid)=5.30e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 29: 9.1s to complete
#     error(train)=4.16e-01, acc(train)=8.60e-01, error(valid)=5.25e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 30: 10.2s to complete
#     error(train)=4.13e-01, acc(train)=8.61e-01, error(valid)=5.23e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 31: 9.7s to complete
#     error(train)=4.08e-01, acc(train)=8.63e-01, error(valid)=5.20e-01, acc(valid)=8.27e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 32: 8.5s to complete
#     error(train)=4.03e-01, acc(train)=8.63e-01, error(valid)=5.19e-01, acc(valid)=8.28e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 33: 9.0s to complete
#     error(train)=4.01e-01, acc(train)=8.64e-01, error(valid)=5.18e-01, acc(valid)=8.28e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 34: 10.4s to complete
#     error(train)=3.92e-01, acc(train)=8.67e-01, error(valid)=5.11e-01, acc(valid)=8.31e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 35: 8.5s to complete
#     error(train)=3.86e-01, acc(train)=8.69e-01, error(valid)=5.08e-01, acc(valid)=8.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 36: 9.5s to complete
#     error(train)=3.84e-01, acc(train)=8.68e-01, error(valid)=5.07e-01, acc(valid)=8.32e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 37: 9.5s to complete
#     error(train)=3.81e-01, acc(train)=8.70e-01, error(valid)=5.07e-01, acc(valid)=8.30e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 38: 8.8s to complete
#     error(train)=3.73e-01, acc(train)=8.72e-01, error(valid)=5.00e-01, acc(valid)=8.35e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 39: 10.1s to complete
#     error(train)=3.71e-01, acc(train)=8.73e-01, error(valid)=5.00e-01, acc(valid)=8.34e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 40: 11.5s to complete
#     error(train)=3.68e-01, acc(train)=8.73e-01, error(valid)=4.99e-01, acc(valid)=8.33e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 41: 9.1s to complete
#     error(train)=3.61e-01, acc(train)=8.76e-01, error(valid)=4.95e-01, acc(valid)=8.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 42: 8.8s to complete
#     error(train)=3.61e-01, acc(train)=8.76e-01, error(valid)=4.97e-01, acc(valid)=8.36e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 43: 10.4s to complete
#     error(train)=3.56e-01, acc(train)=8.78e-01, error(valid)=4.96e-01, acc(valid)=8.35e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 44: 9.9s to complete
#     error(train)=3.55e-01, acc(train)=8.77e-01, error(valid)=4.95e-01, acc(valid)=8.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 45: 9.3s to complete
#     error(train)=3.50e-01, acc(train)=8.79e-01, error(valid)=4.94e-01, acc(valid)=8.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 46: 9.6s to complete
#     error(train)=3.47e-01, acc(train)=8.80e-01, error(valid)=4.90e-01, acc(valid)=8.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 47: 9.8s to complete
#     error(train)=3.43e-01, acc(train)=8.81e-01, error(valid)=4.92e-01, acc(valid)=8.37e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 48: 9.3s to complete
#     error(train)=3.39e-01, acc(train)=8.83e-01, error(valid)=4.85e-01, acc(valid)=8.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 49: 11.2s to complete
#     error(train)=3.38e-01, acc(train)=8.83e-01, error(valid)=4.89e-01, acc(valid)=8.39e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 50: 11.3s to complete
#     error(train)=3.34e-01, acc(train)=8.84e-01, error(valid)=4.86e-01, acc(valid)=8.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 51: 9.5s to complete
#     error(train)=3.31e-01, acc(train)=8.85e-01, error(valid)=4.87e-01, acc(valid)=8.39e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 52: 9.7s to complete
#     error(train)=3.28e-01, acc(train)=8.86e-01, error(valid)=4.84e-01, acc(valid)=8.41e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 53: 11.5s to complete
#     error(train)=3.29e-01, acc(train)=8.85e-01, error(valid)=4.89e-01, acc(valid)=8.38e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 54: 8.8s to complete
#     error(train)=3.23e-01, acc(train)=8.87e-01, error(valid)=4.87e-01, acc(valid)=8.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 55: 9.3s to complete
#     error(train)=3.22e-01, acc(train)=8.87e-01, error(valid)=4.84e-01, acc(valid)=8.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 56: 9.0s to complete
#     error(train)=3.17e-01, acc(train)=8.89e-01, error(valid)=4.82e-01, acc(valid)=8.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 57: 9.2s to complete
#     error(train)=3.15e-01, acc(train)=8.90e-01, error(valid)=4.81e-01, acc(valid)=8.40e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 58: 8.6s to complete
#     error(train)=3.13e-01, acc(train)=8.90e-01, error(valid)=4.80e-01, acc(valid)=8.43e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 59: 10.8s to complete
#     error(train)=3.11e-01, acc(train)=8.90e-01, error(valid)=4.82e-01, acc(valid)=8.43e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 60: 8.8s to complete
#     error(train)=3.09e-01, acc(train)=8.92e-01, error(valid)=4.83e-01, acc(valid)=8.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 61: 9.0s to complete
#     error(train)=3.07e-01, acc(train)=8.91e-01, error(valid)=4.83e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 62: 9.8s to complete
#     error(train)=3.05e-01, acc(train)=8.93e-01, error(valid)=4.84e-01, acc(valid)=8.42e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 63: 9.5s to complete
#     error(train)=3.01e-01, acc(train)=8.94e-01, error(valid)=4.77e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 64: 9.2s to complete
#     error(train)=3.00e-01, acc(train)=8.95e-01, error(valid)=4.79e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 65: 9.6s to complete
#     error(train)=2.96e-01, acc(train)=8.95e-01, error(valid)=4.76e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 66: 10.5s to complete
#     error(train)=2.94e-01, acc(train)=8.96e-01, error(valid)=4.77e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 67: 9.2s to complete
#     error(train)=2.92e-01, acc(train)=8.97e-01, error(valid)=4.78e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 68: 11.6s to complete
#     error(train)=2.90e-01, acc(train)=8.98e-01, error(valid)=4.76e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 69: 9.2s to complete
#     error(train)=2.88e-01, acc(train)=8.98e-01, error(valid)=4.77e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 70: 9.0s to complete
#     error(train)=2.88e-01, acc(train)=8.97e-01, error(valid)=4.79e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 71: 10.1s to complete
#     error(train)=2.86e-01, acc(train)=8.99e-01, error(valid)=4.79e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 72: 8.9s to complete
#     error(train)=2.84e-01, acc(train)=8.98e-01, error(valid)=4.78e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 73: 10.0s to complete
#     error(train)=2.80e-01, acc(train)=9.00e-01, error(valid)=4.79e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 74: 9.4s to complete
#     error(train)=2.81e-01, acc(train)=8.99e-01, error(valid)=4.83e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 75: 9.8s to complete
#     error(train)=2.78e-01, acc(train)=9.00e-01, error(valid)=4.81e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 76: 10.9s to complete
#     error(train)=2.78e-01, acc(train)=9.01e-01, error(valid)=4.80e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 77: 11.7s to complete
#     error(train)=2.77e-01, acc(train)=9.01e-01, error(valid)=4.81e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 78: 9.0s to complete
#     error(train)=2.72e-01, acc(train)=9.03e-01, error(valid)=4.78e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 79: 9.3s to complete
#     error(train)=2.70e-01, acc(train)=9.03e-01, error(valid)=4.80e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 80: 9.7s to complete
#     error(train)=2.70e-01, acc(train)=9.04e-01, error(valid)=4.80e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 81: 9.5s to complete
#     error(train)=2.67e-01, acc(train)=9.05e-01, error(valid)=4.78e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 82: 9.6s to complete
#     error(train)=2.68e-01, acc(train)=9.04e-01, error(valid)=4.82e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 83: 11.2s to complete
#     error(train)=2.64e-01, acc(train)=9.05e-01, error(valid)=4.80e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 84: 9.1s to complete
#     error(train)=2.61e-01, acc(train)=9.06e-01, error(valid)=4.78e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 85: 9.3s to complete
#     error(train)=2.60e-01, acc(train)=9.06e-01, error(valid)=4.79e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 86: 11.6s to complete
#     error(train)=2.58e-01, acc(train)=9.07e-01, error(valid)=4.76e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 87: 9.3s to complete
#     error(train)=2.59e-01, acc(train)=9.07e-01, error(valid)=4.80e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 88: 8.8s to complete
#     error(train)=2.56e-01, acc(train)=9.08e-01, error(valid)=4.81e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 89: 9.5s to complete
#     error(train)=2.57e-01, acc(train)=9.06e-01, error(valid)=4.83e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 90: 13.1s to complete
#     error(train)=2.56e-01, acc(train)=9.07e-01, error(valid)=4.83e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 91: 14.0s to complete
#     error(train)=2.50e-01, acc(train)=9.11e-01, error(valid)=4.79e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 92: 9.7s to complete
#     error(train)=2.51e-01, acc(train)=9.09e-01, error(valid)=4.82e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 93: 10.5s to complete
#     error(train)=2.50e-01, acc(train)=9.09e-01, error(valid)=4.81e-01, acc(valid)=8.48e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 94: 27.1s to complete
#     error(train)=2.47e-01, acc(train)=9.10e-01, error(valid)=4.81e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 95: 15.9s to complete
#     error(train)=2.46e-01, acc(train)=9.11e-01, error(valid)=4.80e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 96: 14.5s to complete
#     error(train)=2.46e-01, acc(train)=9.11e-01, error(valid)=4.83e-01, acc(valid)=8.46e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 97: 13.6s to complete
#     error(train)=2.44e-01, acc(train)=9.11e-01, error(valid)=4.83e-01, acc(valid)=8.45e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 98: 10.6s to complete
#     error(train)=2.41e-01, acc(train)=9.13e-01, error(valid)=4.81e-01, acc(valid)=8.47e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 99: 12.8s to complete
#     error(train)=2.42e-01, acc(train)=9.12e-01, error(valid)=4.83e-01, acc(valid)=8.44e-01
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Epoch 100: 9.4s to complete
#     error(train)=2.41e-01, acc(train)=9.12e-01, error(valid)=4.86e-01, acc(valid)=8.46e-01

# %%
import pickle
with open('droppie97.ob', 'wb') as fp:
    pickle.dump(droppie_97, fp)

# %%
droppie_97[1]
# Out:
# {'error(train)': 0, 'acc(train)': 1, 'error(valid)': 2, 'acc(valid)': 3}

# %%
droppie_97[0][-1][0]
# Out:
# 0.2413236340612245

# %%
# Create model with TWO hidden layers
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), # first hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), # second hidden layer
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init) # output layer
])

error = CrossEntropySoftmaxError()
# Use a Adam learning rule
learning_rule = AdamLearningRule(learning_rate=learning_rate)

# Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
